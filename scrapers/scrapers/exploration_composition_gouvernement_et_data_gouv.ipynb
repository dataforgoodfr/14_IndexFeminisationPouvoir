# %% [markdown]
# # Packages

# %%
import requests
from scrapy import Selector
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
import json
import pandas as pd

# %% [markdown]
# # 1.a Scraper composition du gouvernement

# %% [markdown]
# ## Paramètres

# %%
URL_COMPOSITION_GOUVERNEMENT = "https://www.info.gouv.fr/composition-du-gouvernement"

# %%
html = requests.get(URL_COMPOSITION_GOUVERNEMENT).content

# %%
# Voir les 5000 premiers caractères du HTML
print(html.decode('utf-8')[:5000])

# Chercher si "h3" existe dans le HTML
print("h3" in str(html))
print("fr-card__title" in str(html))
# Out:
# <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt = {cvId: '3',cZone: 'www.info.gouv.fr',cType: 'managed',cRay: '9c8aee193e00ef93',cH: 'kE.WGcnpItWlvKSIcL3COlnswAvfNLT_5jEnfQkpc8s-1770216098-1.2.1.1-98XxzXh.l8RI4.qlCp3qoCStMpkhgu6cxJpeMzzVmhdTfCBD.73qMYk.EPOiKt0k',cUPMDTk:"\/composition-du-gouvernement?__cf_chl_tk=5gtWHWPz6MNRxScIo4Ju9a9__yqcZWtI0Xnum7urqgI-1770216098-1.0.1.1-cOenodfe_ynC2cAKqSdS6E0TQzFDcG9CPUIiRio.JxA",cFPWv: 'b',cITimeS: '1770216098',cTplC:0,cTplV:5,cTplB: '0',fa:"\/composition-du-gouvernement?__cf_chl_f_tk=5gtWHWPz6MNRxScIo4Ju9a9__yqcZWtI0Xnum7urqgI-1770216098-1.0.1.1-cOenodfe_ynC2cAKqSdS6E0TQzFDcG9CPUIiRio.JxA",md: 'v8M7YdLSSYSjjg5wkLpGIniN_RLLmxk08VQ1jJ2Kp4U-1770216098-1.2.1.1-JAOtSDhzN5jqU_SBS2cdipQIXL5H1Fj7WWaTf4GDdBUwtaG3n1TohEBRgTDC7ydO6ljqZOBRUUiEmE9QYQS2a5jXTv0Wqc9kPG2358UhrZ5CAAr_5Q18KQbzbUhFD8XaSSnM5SnnSxyvuSsBFbaSVgof52s0qCrM0k02F.4lJJgnUFbqv7hbwA1zzg67ck55fBPsM91da0aCosSzCxn1E2yYZZYwqQB5W77UiRFSVwqRYRmBqKyog1I0DLhMphfjaV.4rQjco2AXaB0x6fXyZcbibl1fXaFW5bDRAlE1cFGe1oTeSKdJLaj.R0enf60yXuUaurjccqLpxDQHB.IvbSLj1AwDgxvF3GHp00keYYpTum9Eq9RrR7lPmNiPXAnt3oHrc8QqPyvtcFOQQjR85O8guqn1.huiwWoZl9AoD4YId4F04iCuNNXxBEK8o6DD7IAOJdFZh8a2hbsY6ORLQ4rwY_hBMaUfpuS_g3H6VuNf2gsZ1MP.zIf.RYL3vxTDjDXeuVP8Iins.ZAvm_jd_W0VBqyOYEnA4NYiKf3u8DrGeupVBdBW7TsiOa_recbjtLci2bBs17OCyR5HxPtEllu5pLliuSS7QXiiSkHw8t4MtwikyBVm1bxfjjyAKoWAJHi7ptug7pwp.G85XsukwCRCJ2OZO6ASDu45hMPPxZp1dGSlNMIrPrxfiAAJdps6bDRq_MF2gAznWTyYRIRmDmGkLSh5vt1lilMDecQez40bnkqMibLAQi.ZwgdH4opQijQW9V2AvW0tbWRpinkAYq1iQGNjZRnBX12j.VRxgDDClgKb_6eY_2AjjrMKc4_oVxY4TTHBaA.Y_pjpQkQZZzyaAvBASEMBwGw4B_KPqnsGKztqJ9dslOEn0Co2wHl0Qar46zV5i7kva9u6kv2iTpeZ_dHzyuF.XJPZ8Cn7DPjhuOJ2d50kZz374uXPQBYE',mdrd: 'NW.VM.56h9EgsQydoLk3jmb26pjfemY2MaB1S4oUobY-1770216098-1.2.1.1-sHSqgr7KaDBOOE7NUiZCUcYTKtjGq8vPkdnl8DQ_pdpSegS78QdVff1dEOm4k5jocKYvM8U7J0e4cMzJdBoCPbNaX.QHFJCjxn51KhhHSiynL_4oEwEZHFgY5PnZr93L1yrWffcwZV4cCIQh7TDfNmr.6FyFhBHSeVAoH6eRg_V7mr00gmE.7es2SIPd7cc.IyC6V77zABKH2lI1uMHzOWIF7dyKqQy_urCiJqSVYVydjxrtjFmI34ix_hiS084mNsN7LSFgVpJAot2Jv7HLQtiK2DIg27V_EqSsxntbfN_SDZDGX4M06oZkkN5FA7lKc4qO0lKr6T9d7Is_G20IbnX5MeAwG0nsIsw6k5kESZv0sYZEoQiGbUlHfxjUWZShHSGBd38SBZ.2W3Nb6fxWHoF6mzM1XZHExVHUHf_fV7MVeuFoBmx_N6lerZrhhB4SjZG3sSFx2P2KTObZGQhCKfoa7pgFK24iLTPJyKnegxhSorh6vFCRm0YfVzxSLcTuGjnRIF51W_pB2wZt4b.VjnOdp6sR1.nTzdh9nguWv0qPT1DRthl.hcJH.XUib3K3hpziQZ8jjedRGGc.GX9pwiqP.ro4BrPDQ8xxsegXsiSEhgYoYQzzkpUHhWR6DTECxU.mWPpJITgrFOX..TAdDvswkuem_KtkA19TknS2zPP9B9nJpFHIdSuc2XLb5RTBg6WOXCHuczjpXzrZ7qKJ5TMNQ6SjOvNvdj3V.sY4TaXZepJqqEqXkyJJj.e7xNLaS4vvvY4N4l45_NX1t.47ZwsXISnoeZcgFWvnXH3znuXZU4OHgGa6FjIyxbK5Cff92zvo7EJZHNdBeBxaF8GaqTRyb ...
# False
# False

# %% [markdown]
# --> "h3" ne s'affiche pas dans le HTML --> il faut exécuter le JS.

# %%
driver = webdriver.Firefox()
driver.get(URL_COMPOSITION_GOUVERNEMENT)

# Attendre le chargement
time.sleep(3)

html = driver.page_source

sel = Selector(text=html)

# %% [markdown]
# ## Noms des ministres

# %%
noms_ministres = sel.xpath('//h3[@class="fr-card__title"]//a[contains(@href, "personnalite")]/text()').extract()

# Nettoyage : suppression des espaces et des "\n"
noms_ministres = [nom.strip() for nom in noms_ministres]
noms_ministres
# Out:
# ['Sébastien Lecornu',
#  'Laurent Panifous',
#  'Maud Bregeon',
#  'Aurore Bergé',
#  'Laurent Nunez',
#  'Marie-Pierre Vedrenne',
#  'Catherine Vautrin',
#  'Alice Rufo',
#  'Jean-Pierre Farandou',
#  'Monique Barbut',
#  'Catherine Chabaud',
#  'Mathieu Lefèvre',
#  'Gérald Darmanin',
#  'Roland Lescure',
#  'Sébastien Martin',
#  'Anne Le Henanff',
#  'Serge Papin',
#  'Annie Genevard',
#  'Édouard Geffray',
#  'Jean-Noël Barrot',
#  'Benjamin Haddad',
#  'Nicolas Forissier',
#  'Éléonore Caroit',
#  'Rachida Dati',
#  'Stéphanie Rist',
#  'Charlotte Parmentier-Lecocq',
#  'Naïma Moutchou',
#  'Françoise Gatel',
#  'Michel Fournier',
#  'Amélie de Montchalin',
#  'David Amiel',
#  'Philippe Baptiste',
#  'Marina Ferrari',
#  'Philippe Tabarot',
#  'Vincent Jeanbrun']

# %% [markdown]
# ## Fonctions

# %%
fonctions_ministres = sel.xpath('//p[@class="fr-card__desc"]/text()').extract()

# Nettoyage : suppression des espaces et des "\n"
fonctions_ministres = [fonction.strip() for fonction in fonctions_ministres]
fonctions_ministres
# Out:
# ['Premier ministre',
#  'Ministre délégué auprès du Premier ministre, chargé des Relations avec le Parlement',
#  'Ministre déléguée auprès du Premier ministre, porte-parole du Gouvernement',
#  "Ministre déléguée auprès du Premier ministre, chargée de l'Égalité entre les femmes et les hommes et de la Lutte contre les discriminations",
#  'Ministre de l’Intérieur',
#  'Ministre déléguée auprès du ministre de l’Intérieur',
#  'Ministre des Armées et des Anciens combattants',
#  'Ministre déléguée auprès de la ministre des Armées et des Anciens combattants',
#  'Ministre du Travail et des Solidarités',
#  'Ministre de la Transition écologique, de la Biodiversité et des Négociations internationales sur le climat et la nature',
#  'Ministre déléguée auprès de la ministre de la Transition écologique, de la Biodiversité et des Négociations internationales sur le climat et la nature, chargée de la Mer et de la Pêche',
#  'Ministre délégué auprès de la ministre de la Transition écologique, de la Biodiversité et des Négociations internationales sur le climat et la nature, chargé de la Transition écologique',
#  'Garde des Sceaux, ministre de la Justice',
#  'Ministre de l’Économie, des Finances et de la Souveraineté industrielle, énergétique et numérique',
#  "Ministre délégué auprès du ministre de l’Économie, des Finances et de la Souveraineté industrielle, énergétique et numérique, chargé de l'Industrie",
#  'Ministre déléguée auprès du ministre de l’Économie, des Finances et de la Souveraineté industrielle, énergétique et numérique, chargée de l’Intelligence artificielle et du Numérique',
#  'Ministre des Petites et moyennes entreprises, du Commerce, de l’Artisanat, du Tourisme et du Pouvoir d’achat',
#  'Ministre de l’Agriculture, de l’Agro-alimentaire et de la Souveraineté alimentaire.',
#  'Ministre de l’Éducation nationale',
#  'Ministre de l’Europe et des Affaires étrangères',
#  'Ministre délégué auprès du ministre de l’Europe et des Affaires étrangères, chargé de l’Europe',
#  "Ministre délégué auprès du ministre de l’Europe et des Affaires étrangères, chargé du Commerce extérieur et de l'Attractivité",
#  'Ministre déléguée auprès du ministre de l’Europe et des Affaires étrangères, chargée de la Francophonie, des Partenariats internationaux et des Français de l’étranger',
#  'Ministre de la Culture',
#  'Ministre de la Santé, des Familles, de l’Autonomie et des Personnes handicapées',
#  'Ministre déléguée auprès de la ministre de la Santé, des Familles, de l’Autonomie et des Personnes handicapées, chargée de l’Autonomie et des Personnes handicapées',
#  'Ministre des Outre-mer',
#  'Ministre de l’Aménagement du territoire et de la Décentralisation',
#  'Ministre délégué auprès de la ministre de l’Aménagement du territoire et de la Décentralisation, chargé de la Ruralité',
#  'Ministre de l’Action et des Comptes publics',
#  'Ministre délégué auprès de la ministre de l’Action et des Comptes publics, chargé de la Fonction publique et de la Réforme de l’État',
#  'Ministre de l’Enseignement supérieur, de la Recherche et de l’Espace',
#  'Ministre des Sports, de la Jeunesse et de la Vie associative',
#  'Ministre des Transports',
#  'Ministre de la Ville et du Logement']

# %% [markdown]
# # Scrapers API
# Exploration de toutes les sources dispo par API sur data.gouv.fr :
# - https://www.data.gouv.fr/datasets/repertoire-national-des-elus-1/reuses_and_dataservices
# - Exemple liste députés avec liste déroulante pour choisir les instances en haut : https://explore.data.gouv.fr/fr/datasets/5c34c4d1634f4173183a64f1/#/resources/1ac42ff4-1336-44f8-a221-832039dbc142
#
# **A priori max page = 200**

# %% [markdown]
# ## URLs des différentes données

# %%
# Députées 2a
URL_DEPUTEES = f"https://tabular-api.data.gouv.fr/api/resources/1ac42ff4-1336-44f8-a221-832039dbc142/data/?page=2&page_size=10"

# Conseillères départementales 6a
URL_CONSEILLERES_DEPARTEMENTALES = f"https://tabular-api.data.gouv.fr/api/resources/601ef073-d986-4582-8e1a-ed14dc857fba/data/"

# Conseillères régionales 7a
URL_CONSEILLERES_REGIONALES = f"https://tabular-api.data.gouv.fr/api/resources/430e13f9-834b-4411-a1a8-da0b4b6e715c/data/"

# Sénatrices 3a
URL_SENATRICES = f"https://tabular-api.data.gouv.fr/api/resources/b78f8945-509f-4609-a4a7-3048b8370479/data/"

# Maires 5b
URL_MAIRES = f"https://tabular-api.data.gouv.fr/api/resources/2876a346-d50c-4911-934e-19ee07b0e503/data/"

# %% [markdown]
# ## Paramètres pour les requêtes API

# %%
# Choix de la donnée à récupérer à partir de l'URL
URL = URL_SENATRICES

# Nombre de pages à récupérer
NB_PAGES = 2

# Tailles de chaque page récupérée (max. 200)
PAGE_SIZE = 200

# %% [markdown]
# ## Requête API

# %%
df_final = pd.DataFrame()

for page in range(1, NB_PAGES + 1):
    # Détermination de l'URL en fonction de la page et de la taille de page
    URL_PAGE = f"{URL}?page={page}&page_size={PAGE_SIZE}"

    # Requête
    response = requests.get(
            url = URL_PAGE,
            timeout=20
            )

    if response.status_code == 200:
        try:
            resultat_api = json.loads(response.text)
        except json.JSONDecodeError as exc:
            print("Impossible de décoder le JSON :", exc)
            raise

    data = resultat_api['data']
    data = pd.DataFrame(data)
    df_final = pd.concat([df_final, data], ignore_index=True)
    
df_final
# Out:
#      __id Code du département Libellé du département  \
# 0       1                  01                    Ain
# 1       2                  01                    Ain
# 2       3                  01                    Ain
# 3       4                  02                  Aisne
# 4       5                  02                  Aisne
# ..    ...                 ...                    ...
# 343   344                None                   None
# 344   345                None                   None
# 345   346                None                   None
# 346   347                None                   None
# 347   348                None                   None
#
#     Code de la collectivité à statut particulier  \
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# ..                                           ...
# 343                                          986
# 344                                          987
# 345                                          987
# 346                                          988
# 347                                          988
#
#     Libellé de la collectivité à statut particulier    Nom de l'élu  \
# 0                                              None  BLATRIX CONTAT
# 1                                              None          CHAIZE
# 2                                              None     GOY-CHAVENT
# 3                                              None           GRUNY
# 4                                              None         LEFEVRE
# ..                                              ...             ...
# 343                                Wallis Et Futuna     KULIMOETOKE
# 344                             Polynésie Française      ROHFRITSCH
# 345                             Polynésie Française        TETUANUI
# 346                              Nouvelle-Calédonie         NATUREL
# 347                              Nouvelle-Calédonie           XOWIE
#
#     Prénom de l'élu Code sexe Date de naissance  \
# 0          Florence         F        1966-03-30
# 1           Patrick         M        1963-03-22
# 2            Sylvie         F        1963-05-23
# 3           Pascale         F        1960-02-18
# 4           Antoine         M        1966-02-18
# ..              ...       ...               ...
# 343         Mikaele         M        1963-06-17
# 344            Teva         M        1975-03-02
# 345            Lana         F        1970-02-23
# 346         Georges         M        1955-11-21
# 347          Robert         M        1962-08-29
#
#      Code de la catégorie socio-professionnelle  \
# 0                                            34
# 1                                            85
# 2                                            34
# 3                                            37
# 4                                            74
# ..                                          ...
# 343                                          53
# 344                                          23
# 345                                          45
# 346                                          74
# 347                                          33
#
#          Libellé de la catégorie socio-professionnelle Date de début du mandat
# 0                  Professeur, profession scientifique              2020-01-10
# 1    Personne diverse sans activité professionnelle...              2020-01-10
# 2                  Professeur, profession scientifique              2020-01-10
# 3       Cadre administratif et commercial d'entreprise              2020-01-10
# 4                                         Ancien cadre              2020-01-10
# ..                                                 ...                     ...
# 343                              Policier et militaire              2020-01-10
# 344           Chef d'entreprise de 10 salariés ou plus              2020-01-10
# 345  Profession intermédiaire administrative de la ...              2020-01-10
# 346                                       Ancien cadre              2023-02-10
# 347                      Cadre de la fonction publique              2023-02-10
#
# [348 rows x 12 columns]

# %% [markdown]
# ## Conservation des données qui nous intéressent
# Nom, prénom, sexe, date début mandat, localisation, parti politique

# %%
df_traite = df_final[["Code du département", "Libellé du département", "Nom de l'élu", "Prénom de l'élu", "Code sexe", "Date de début du mandat"]]
df_traite
# Out:
#     Code du département Libellé du département    Nom de l'élu  \
# 0                    01                    Ain  BLATRIX CONTAT
# 1                    01                    Ain          CHAIZE
# 2                    01                    Ain     GOY-CHAVENT
# 3                    02                  Aisne           GRUNY
# 4                    02                  Aisne         LEFEVRE
# ..                  ...                    ...             ...
# 343                None                   None     KULIMOETOKE
# 344                None                   None      ROHFRITSCH
# 345                None                   None        TETUANUI
# 346                None                   None         NATUREL
# 347                None                   None           XOWIE
#
#     Prénom de l'élu Code sexe Date de début du mandat
# 0          Florence         F              2020-01-10
# 1           Patrick         M              2020-01-10
# 2            Sylvie         F              2020-01-10
# 3           Pascale         F              2020-01-10
# 4           Antoine         M              2020-01-10
# ..              ...       ...                     ...
# 343         Mikaele         M              2020-01-10
# 344            Teva         M              2020-01-10
# 345            Lana         F              2020-01-10
# 346         Georges         M              2023-02-10
# 347          Robert         M              2023-02-10
#
# [348 rows x 6 columns]

# %% [markdown]
# ## Calcul ratio de femmes

# %%
df_traite["Code sexe"].value_counts()
# Out:
# Code sexe
# M    215
# F    133
# Name: count, dtype: int64

# %%
nombre_de_femmes = df_traite["Code sexe"].value_counts().get("F", 0)
nombre_d_hommes = df_traite["Code sexe"].value_counts().get("M", 0)
ratio_femmes = nombre_de_femmes / (nombre_de_femmes + nombre_d_hommes) * 100
print(f"Il y a {nombre_de_femmes} femmes sur {nombre_de_femmes + nombre_d_hommes} représentant(e)s, soit un ratio de {ratio_femmes:.1f}% de femmes.")
# Out:
# Il y a 133 femmes sur 348 représentant(e)s, soit un ratio de 38.2% de femmes.
